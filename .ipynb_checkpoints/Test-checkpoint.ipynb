# %%
import backend
# Out:
# [[2. 3. 3.]
#  [4. 5. 6.]
#  [7. 7. 8.]]

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

path = "./Test_Photos/underexposed-original.jpg"
img = Image.open(path)
img = img.convert('RGBA')
img_array = np.array(img)
plt.imshow(img_array)

# %%
not_Grainy = backend.histEq(img_array)
# smooth = backend.imgDenoising_Gaussian(not_Grainy, 1)
# sharpened = backend.unsharpMask(not_Grainy, 5)
plt.imshow(not_Grainy)
